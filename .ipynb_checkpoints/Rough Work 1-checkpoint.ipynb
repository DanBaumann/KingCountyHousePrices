# %% [markdown]
# # Gathering information about our data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import norm
import seaborn as sns

# %%
kc_house_data = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# import pandas_profiling

# %% [markdown]
# profile = kc_house_data.profile_report(title='Pandas Profiling Report')
# profile.to_file(output_file="output.html")

# %%
display(kc_house_data.head())
kc_house_data.columns
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
kc_house_data.shape #how many rows and columns
# Out:
# (21597, 21)

# %%
kc_house_data.info() #gives a brief overview on missing data
# most seem to have all data, apart from waterfront, view, yr_renovated
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
kc_house_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# std    4.141264e+04      0.539683      0.086825      0.765686      0.650546
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068500e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above      yr_built  yr_renovated       zipcode  \
# count  21597.000000  21597.000000  21597.000000  17755.000000  21597.000000
# mean       7.657915   1788.596842   1970.999676     83.636778  98077.951845
# std        1.173200    827.759761     29.375234    399.946414     53.513072
# min        3.000000    370.000000   1900.000000      0.000000  98001.000000
# 25%        7.000000   1190.000000   1951.000000      0.000000  98033.000000
# 50%        7.000000   1560.000000   1975.000000      0.000000  98065.000000
# 75%        8.000000   2210.000000   1997.000000      0.000000  98118.000000
# max       13.000000   9410.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21597.000000  21597.000000   21597.000000   21597.000000
# mean      47.560093   -122.213982    1986.620318   12758.283512
# std        0.138552      0.140724     685.230472   27274.441950
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.471100   -122.328000    1490.000000    5100.000000
# 50%       47.571800   -122.231000    1840.000000    7620.000000
# 75%       47.678000   -122.125000    2360.000000   10083.000000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %%
kc_house_data.isna().sum()
# as of now, doesn't seem to be any column with a large proportion of missing data, so no need to drop any right now
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [markdown]
# # End goal is to create a multiple linear regression with exogenous variables (i.e. sqr footage, waterfront)
# # to predict our endogenous variable (Regressand) in house prices

# %% [markdown]
# # the dataset contains 21597 observations
# # the dataset contains 18 variables we can use in our regression
# # 1. bedrooms - no. of bedrooms (0.5 Bedroom or Half Bedroom means its length and breadth will be less than 10 ft)
# # 2. bathrooms - no. of bathrooms (0.5 bathroom indicates just toilet and sink, no tub or shower)
# # 3. sqft_living - square footage of the home only
# # 4. sqft_lot - square footage of the lot
# # 5. floors - how many floors are in the house
# # 6. waterfront - does the property have a view to waterfront - binary variable (0 means no, 1 means yes)
# # 7. view - how many times the property has been viewed
# # 8. condition - 1-5 rating of condition. Higher is better (i think)
# # 9. grade - construction quality of improvements on a scale of 1-13
# # 10. sqft_above - square footage of house excluding basement
# # 11. sqft_basement - square footage of basement
# # 12. yr_built
# # 13. yr_renovated
# # 14. zipcode
# # 15. lat - latitude
# # 16. long - longitude
# # 17. sqft_living15 - if renovation took place in 2015 this should be different to sqft_living
# # 18. sqft_lot15 - if renovation took place in 2015 this should be different to sqft_lot

# %%
# some questions we could ask. Anomalous values?
# which variables have a lot of missing data?
# how are variables distributed?
# problem of multicolinearity i.e. is no. of bedrooms highly correlated with no. of bathrooms
#     could we drop some variables if we think this is a problem?
# how many properties were renovated in 2015?
# are houses that are renovated more valuable on average? 
# look at correlation between some variables and prices

# %% [markdown]
# # How house size as changed over time

# %%
ax = sns.scatterplot(x = 'yr_built', y = 'sqft_living', data = kc_house_data)

# %%
average_by_year = kc_house_data.groupby('yr_built').mean()
average_by_year
# Out:
#                     id          price  bedrooms  bathrooms  sqft_living  \
# yr_built
# 1900      5.060402e+09  514065.367816  3.183908   1.709770  1703.620690
# 1901      5.036920e+09  530211.793103  3.310345   1.577586  1763.620690
# 1902      4.280460e+09  557266.666667  3.444444   1.925926  1737.777778
# 1903      4.508135e+09  468566.891304  3.043478   1.505435  1507.739130
# 1904      4.542878e+09  507645.533333  2.800000   1.461111  1474.288889
# ...                ...            ...       ...        ...          ...
# 2011      4.787524e+09  486648.384615  3.484615   2.586538  2212.030769
# 2012      5.149959e+09  476995.805882  3.541176   2.558824  2278.858824
# 2013      4.447780e+09  534425.452736  3.746269   2.680348  2419.825871
# 2014      4.482581e+09  560629.268336  3.706619   2.638193  2469.844365
# 2015      5.255062e+09  559181.473684  3.710526   2.559211  2366.578947
#
#              sqft_lot    floors  waterfront  view  condition     grade  \
# yr_built
# 1900      5028.448276  1.505747         0.0   0.0   3.574713  6.977011
# 1901      4142.931034  1.568966         0.0   0.0   3.724138  7.103448
# 113  5573.462687  2.042289         0.0   0.0   3.000000  8.009950
# 114  4965.159213  2.126118         0.0   0.0   3.000000  8.200358
# 115  4295.552632  2.223684         0.0   0.0   3.000000  8.236842
#
#       sqft_above  yr_renovated       zipcode        lat        long  \
# 0    1464.080460           0.0  98104.655172  47.594106 -122.293793
# 1    1513.620690           0.0  98121.000000  47.630710 -122.329793
# 2    1784.074074           0.0  98116.518519  47.616689 -122.314556
# 3    1402.869565           0.0  98105.608696  47.591474 -122.303587
# 4    1206.511111           0.0  98117.933333  47.609891 -122.316822
# ..           ...           ...           ...        ...         ...
# 111  2046.492308           0.0  98063.053846  47.522833 -122.169854
# 112  2137.329412           0.0  98062.041176  47.501455 -122.150818
# 113  2200.099502           0.0  98066.348259  47.526551 -122.180886
# 114  2170.486583           0.0  98076.533095  47.549836 -122.210658
# 115  1881.052632           0.0  98103.578947  47.616995 -122.260895
#
#      sqft_living15   sqft_lot15
# 0      1667.114943  4945.379310
# 1      1530.965517  3947.862069
# 2      1815.925926  4325.555556
# 3      1537.608696  4995.934783
# 4      1577.555556  4600.066667
# ..             ...          ...
# 111    2126.746154  4792.146154
# 112    2174.129412  5083.358824
# 113    2215.124378  5763.104478
# 114    2088.522361  5311.624329
# 115    1802.105263  4553.868421
#
# [116 rows x 19 columns]

# %%
plt.scatter(x, y)

# %% [markdown]
# # PRICE ANALYSIS

# %% [markdown]
# Price is our outcome of interest, this task requires us to use all the variables to create a good prediction of price

# %%
kc_house_data.price.hist(bins = 50, figsize = (15,8))
# price has median 450,000, mean of 540296
# positive skew with very high kurtosis

# %% [markdown]
# # BEDROOMS ANALYSIS

# %%
kc_house_data.loc[(kc_house_data['bedrooms'] == 33 )]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895  6/25/2014  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 15856      6000     1.0         0.0   0.0  ...      7        1040
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 15856          580.0     1947           0.0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15856           1330        4700
#
# [1 rows x 21 columns]

# %%
kc_house_data.bedrooms.value_counts()
# minimum of 3 bedrooms, 11 and 33 bedrooms represent a very small proportion of data set, so let's drop these rows
# generally the rule is 1.5*IQR above q3 or below q1. these values are considered outliers
# in this case, it would suggest dropping any propoerties with more than 5.5 bedrooms i.e. 6 or more
# mode of 3, median of 3 and mean of 3.37
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
# to illustrate these outliers, can use a histrogram
kc_house_data.bedrooms.hist(bins = 20)
# the outliers, especially at 33 makes this histogram look bad

# %%
# rule of thumb for dropping outliers is 1.5* IQR +- Q3,Q1 is considered an outlier
# this means dropping houses with 1 bedroom, and 6 or more 
bedrooms_outliers_dropped = kc_house_data[~(kc_house_data['bedrooms'] > 5) & ~(kc_house_data['bedrooms'] < 1.5)]['bedrooms']
bedrooms_outliers_dropped.hist(bins = 4)
# this is our new histogram with outliers dropped 
# exhibits some positive skew and high kurtosis (much greater than a normal distribution)
# this means that the vast majority of data is around the median value
bedrooms_outliers_dropped.value_counts().sum()
# 530 observations are dropped here
# create new dataset with kc_house
# Out:
# 21067

# %% [markdown]
# # BATHROOMS ANALYSIS

# %%
kc_house_data.bathrooms.value_counts()
# 0.5 bathrooms = toilet and sink
# 0.25 indicates only a sink
# mode is 2.50 bathrooms, median is 2.25, mean is 2.1
# Out:
# 2.50    5377
# 1.00    3851
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1445
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      71
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 1.25       9
# 6.00       6
# 5.75       4
# 0.50       4
# 8.00       2
# 6.25       2
# 6.75       2
# 6.50       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
kc_house_data.bathrooms.hist(bins = 10)
# definite positive skew
